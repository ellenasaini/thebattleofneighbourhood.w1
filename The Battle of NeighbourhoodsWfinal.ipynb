# %% [markdown]
# # The Battle of Neighbourhoods (week 1)

# %% [markdown]
# ## Opening a Malay Cuisine Restaurant in Kuala Lumpur¶

# %% [markdown]
# # 1. Introduction
# ## background of Malaysia and target audience

# %% [markdown]
# Kuala Lumpur is a robust city in Southeast Asia that proudly claims they have the most scrumtious food to ever exist.
#
# Besides that, Petronas Twin Towers, pair of the tallest skyscraper office buildings are located in Kuala Lumpur.
#
# The city-state is strongly populated and home to nearly 1.8 million people of four ethnic groups: The Chinese, Malay and Indian majority.
#
# The multi-culture has contributed to the diverse culinary field. Though One can easily spot an eclectic mix of restaurants from all over the world.
#
# It is still highly profitable to open a restaurant on the main streets and malls of Kuala Lumpur.
#
# Taking into account the high population densities and the increasing number of tourists.
#
# Since Malays occupy most of the inhabitants,the restaurant is Malay.
#
# This capstone project we will help potential stakeholders select prime locations to open the restaurant.

# %% [markdown]
# ## Target Audiences

# %% [markdown]
# Group 1 : Potential stakeholders who want to invest in opening a Malay restaurant.
#
# This project will help them narrow down their location options.
#
# Group 2: Citizens who want to have a clearer idea of KL neighbourhoods .
#
# This project is helpful when they want to find the top popular venues around a specific area.
#
# Group 3: Tourists in KL. This project provides them with an idea of every neighbourhood and the list of restaurants,
#
# and would be helpful when they want to find a restaurant for meals but have no idea where to go.

# %% [markdown]
# ## Creating and Solving Problems

# %% [markdown]
# We believe a stakeholder would like to open a Malay restaurant in Kuala Lumpur, and have not yet agreed on the spot.
#
# He is not well acquainted with the city and has asked us to suggest areas or locations where he can open his restaurant.
#
# When choosing the optimal spot, other factors must be taken into account.
#
# - choosing a location where Malay food is not common among the neighbouorhood.
# - areas surrounded by entertainment or work places.

# %% [markdown]
# # Data Collection
#
#
# ## In this project we will explore the neighbourhoods in the level of Planning Area. Retrieving venue data around each Planning Area and select Planning Areas as the 'best' locations to open a Malay restaurant.
#
#
# https://en.wikipedia.org/wiki/Category:Suburbs_in_Kuala_Lumpur is the link for Data of Kuala Lumpur Planning Area boundaries
#
#
# I used Foursquare's 'explore' API call to get the information of venues around each Planning Area.
#
# Foursquare is a location data provider with information about all manner of venues and events within an area of interest.
#
# Such information includes venue names, locations, latitudes, longitudes, etc.
#
# For each Planning Area, we have chosen the radius to be 2000 meters.
#
# We only captured the venue data useful for us and populated it into a dataframe named venues_df.
#
# Figure 3 describes the detailed venue data in the dataframe venues_df.
