# %% [markdown]
# # Data Collection

# %% [markdown]
# ##  In this project we will explore the neighbourhoods in the level of Planning Area. Retrieving venue data around each Planning Area and select Planning Areas as the 'best' locations to open a Malay restaurant.

# %% [markdown]
# https://www.dbkl.gov.my/pskl2020/english/land_use_and_development_strategy/index.htm is the link for Data of Kuala Lumpur Planning Area boundaries.

# %%
# Out:
#   File "<ipython-input-38-1f053612aa4f>", line 3
#     import "klstruct.csv" as df
#                         ^
# SyntaxError: invalid syntax
